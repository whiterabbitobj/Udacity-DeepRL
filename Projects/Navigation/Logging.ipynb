# %%
from data_handling import Logger
import numpy as np
import matplotlib.pyplot as plt
import importlib

# %%
import data_handling
importlib.reload(data_handling)
from data_handling import Logger

# %%
logger = Logger()
logger.agent_count = 1
# Out:
# Blank init for Logger object.

# %%
logger.graph(logdir="saves/DDQN_20190312_v3/logs")
# Out:
# ######################################################################
# Saved graph data to: saves/DDQN_20190312_v3/DDQN_20190312_v3_graph.png
# ######################################################################

# %%
import os.path
os.path.dirname("saves/DDQN_20190312_v3/logs")
# Out:
# 'saves/DDQN_20190312_v3'
